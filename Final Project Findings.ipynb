# %% [markdown]
# # Capstone Project: Consumer Insights Data Analytics Externship of Beats by Dre

# %% [markdown]
# ## 1. Title
# **Project Title:** Consumer Insights Data Analytics Externship of Beats by Dre
# **Student Name:** Bhavya Sharma
# **Date:** 29 July 2024

# %% [markdown]
# ## 2. Table of Contents
# 1. Introduction
# 2. Data Description
# 3. Exploratory Data Analysis (EDA)
# 4. Sentiment Analysis
# 5. AI-Generated Insights
# 6. Comparative Analysis
# 7. Strategic Recommendations
# 8. Conclusion
# 9. References

# %% [markdown]
# ## 3. Introduction
#
# ### 3.1 Project Overview

# %% [markdown]
# Purpose of the Project:
# The purpose of this project was to understand customer sentiments towards Beats by Dre products by analyzing reviews from various sources. This understanding would help Beats shape future strategies and product developments, ensuring they meet customer expectations and address any concerns effectively.
#
#
#
#
#
# Key Objectives:
# 1. Data Collection:
#    - Use Python to mine customer reviews from Amazon and other review websites.
#
# 2. Data Processing:
#    - Clean and preprocess the collected data to remove irrelevant details and errors, ensuring it is ready for accurate analysis.
#
# 3. Pattern and Trend Analysis:
#    - Analyze patterns and trends in the data using statistical tools and visualizations to uncover initial insights into customer behavior and preferences.
#
# 4. Sentiment Analysis:
#    - Employ artificial intelligence techniques to analyze sentiments expressed in the reviews, categorizing them into positive, negative, or neutral.
#
# 5. Insight Extraction:
#    - Extract meaningful insights from the sentiment analysis to understand customer preferences and pain points, highlighting areas for potential improvement in products and services.
#
# 6. Presentation of Findings:
#    - Compile all findings into a clear and concise presentation, showcasing key customer sentiments and providing recommendations for potential improvements to the Beats team.

# %% [markdown]
# ### 3.2 Background

# %% [markdown]
# Background for Beats by Dre:
# Beats by Dre is a leading audio brand founded by Dr. Dre and Jimmy Iovine. The company is renowned for its high-quality headphones, earphones, and speakers, which have gained a
# significant following for their premium sound quality and stylish designs. Acquired by Apple Inc. in 2014, Beats continues to innovate in the audio industry, integrating
# cutting-edge technology with its products to enhance user experiences.
#
# Importance of Consumer Sentiment Analysis in the Tech Industry:
# Consumer sentiment analysis is crucial in the tech industry as it provides companies with valuable insights into customer opinions, preferences, and pain points. By analyzing
# customer reviews and feedback, companies can:
# 1. Identify product strengths and weaknesses: Understanding what customers appreciate or dislike about products helps in making informed decisions about product improvements and
# future developments.
# 2. Enhance customer satisfaction: Addressing negative feedback and improving product features based on customer sentiments leads to higher customer satisfaction and loyalty.
# 3. Drive innovation: Insights from sentiment analysis can inspire new ideas and innovations that align with customer needs and market trends.
# 4. Improve marketing strategies: Analyzing customer sentiments helps tailor marketing campaigns to resonate with target audiences, enhancing the effectiveness of promotional efforts.
# 5. Stay competitive: Continuously monitoring and analyzing customer feedback ensures that companies remain responsive to market demands and maintain a competitive edge.
#
# Overall, consumer sentiment analysis empowers tech companies like Beats by Dre to make data-driven decisions, fostering growth and ensuring their products meet the evolving expectations of their customers.

# %% [markdown]
# ## 4. Data Description
#
# ### 4.1 Data Sources

# %% [markdown]
# The primary source of data for this project was Amazon product reviews. I collected reviews for the selected products using the Oxylabs API, a tool that facilitates web scraping and
# data extraction from various websites, including e-commerce platforms like Amazon. The Oxylabs API provided a reliable and efficient way to access review data at scale, ensuring that
# the extracted information was accurate and up-to-date. This method allowed the gathering of comprehensive reviews, including customer feedback, ratings, and other relevant details, which
# were crucial for subsequent data analysis and sentiment analysis tasks.

# %% [markdown]
# ### 4.2 Data Collection

# %% [markdown]
# Data Gathering Process:
# The data gathering process involved the following steps:
#
# 1. Selecting Products:
#    - I identified 12 products on Amazon with a substantial number of reviews.
#    - I, then, ensured that two products were from Beats and the remaining ten were from different brands and competitors.
#
# 2. Using Oxylabs API for Data Collection:
#    - I utilized the Oxylabs API to scrape reviews for the selected products from Amazon.
#    - The API allowed for efficient extraction of review data, including product names, review content, ratings, and timestamps.
#
# 3. Saving Reviews:
#    - I compiled and saved the gathered reviews into a structured dataset for further analysis.
#    - The dataset included fields such as review ID, product ID, title, author, rating, content, timestamp, profile ID, is_verified, helpful_count, and product attributes.
#
#
# Challenges Faced and How They Were Overcome:
#
# 1. Challenge: API Rate Limits and Data Quotas
#    Solution: The Oxylabs API had rate limits and data quotas, which could restrict the volume of data collected in a given time frame. WThis was addressed by carefully scheduling API
#    calls to stay within the limits and prioritizing data collection for products with the most reviews.
#
# 2. Challenge: Managing Large Volumes of Data
#    Solution: The large volume of reviews required efficient data handling. So the reviews were stored in optimized formats like CSV and JSON for easy access and analysis.
#
# 4. Challenge: Ensuring Data Accuracy and Relevance
#    Solution: Ensuring the accuracy and relevance of the scraped data was essential. Thorough data validation and cleaning processes, irrelevant information, duplicates, and errors
#    were removed.

# %% [markdown]
# ### 4.3 Data Cleaning

# %% [markdown]
# Following are the steps/code cells involved in data cleaning:
#
# 1. Identifying Datatypes of Columns:
#    - The first step in the data cleaning process was to identify the datatypes of each column in the dataset. This provided an understanding of the structure of the data and helped
#      in planning further preprocessing steps.
#
# 2. Handling Null Values:
#    - After identifying the datatypes, the next step was to check for null values in the dataset. Null values can lead to inaccuracies in analysis, so it was important to address them.
#    - For this dataset, all null values were handled by replacing them with the placeholder "not available." This approach ensured that the missing data did not skew the analysis
#      while still indicating that certain information was unavailable.
#
# 3. Descriptive Statistics Analysis:
#    - Using the `df.describe()` function, a summary of statistics for numerical columns was generated. This included measures such as mean, median, standard deviation, minimum and
#      maximum values, and quartiles. This step provided insights into the distribution and spread of the data.
#
# 4. Calculating Interquartile Range (IQR) for Helpful Count:
#    - To better understand the distribution of the `helpful_count` column, the Interquartile Range (IQR) was calculated. The IQR is a measure of statistical dispersion and is useful
#      for identifying outliers.
#    - Significant decisions included whether to remove outliers or keep them, based on their potential impact on the analysis. In this case, the outliers were retained to fully
#      represent the variability in customer feedback.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
reviews_df = pd.read_csv('/content/drive/MyDrive/merged_reviews.csv')
reviews_df
# Out:
#            review_id  product_id  \
# 0     R20IRE5X6WY351  B085296FLT
# 1      RFGOLBEISEB55  B085296FLT
# 2     R2399XIITPW93N  B085296FLT
# 3     R1S3QWGEJLIK7Q  B085296FLT
# 4     R2T8PKNM1Q1XQK  B085296FLT
# ...              ...         ...
# 1195  R3OXSZT5T74ZFF  B0CCBKGDJD
# 1196  R1ZAEIMTC3EZGP  B0CCBKGDJD
# 1197  R35OTVSHNLWLNM  B0CCBKGDJD
# 1198  R1TSFDSW55DPVP  B0CCBKGDJD
# 1199  R382N0B8E1EZP4  B0CCBKGDJD
#
#                                                   title           author  \
# 0                  5.0 out of 5 stars Great headphones!   Talia Calazans
# 1                  5.0 out of 5 stars Great Headphones!  Leosha Williams
# 2                        5.0 out of 5 stars Works great      Max Rundell
# 3                 5.0 out of 5 stars amazing headphones              N/a
# 4                              5.0 out of 5 stars Whew!          I Allen
# ...                                                 ...              ...
# ...

# %%
#Datatypes of the columns present in the dataframe:
reviews_df.dtypes
# Out:
# review_id             object
# product_id            object
# title                 object
# author                object
# rating                 int64
# content               object
# timestamp             object
# profile_id            object
# is_verified             bool
# helpful_count          int64
# product_attributes    object
# dtype: object

# %%
#Colulmns present in the dataframe:
reviews_df.columns
# Out:
# Index(['review_id', 'product_id', 'title', 'author', 'rating', 'content',
#        'timestamp', 'profile_id', 'is_verified', 'helpful_count',
#        'product_attributes'],
#       dtype='object')

# %%
reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   review_id           1200 non-null   object
#  1   product_id          1200 non-null   object
#  2   title               1200 non-null   object
#  3   author              1199 non-null   object
#  4   rating              1200 non-null   int64
#  5   content             1199 non-null   object
#  6   timestamp           1200 non-null   object
#  7   profile_id          1200 non-null   object
#  8   is_verified         1200 non-null   bool
#  9   helpful_count       1200 non-null   int64
#  10  product_attributes  1099 non-null   object
# dtypes: bool(1), int64(2), object(8)
# memory usage: 95.0+ KB

# %%
#Sum of all null values prsent in the dataframe:
reviews_df.isna().sum()
# Out:
# review_id               0
# product_id              0
# title                   0
# author                  1
# rating                  0
# content                 1
# timestamp               0
# profile_id              0
# is_verified             0
# helpful_count           0
# product_attributes    101
# dtype: int64

# %% [markdown]
# So, from the above output it can be observed that there are 101 null values in 'product attributes' column and 1 null value in 'author' column and 1 null value in content column while all other columns have zero null values.

# %%
#Replacing the null values in the dataframe with 'Not Available':

reviews_df['author'].fillna('Not available', inplace=True)
reviews_df['content'].fillna('Not available', inplace=True)
reviews_df['product_attributes'].fillna('Not available', inplace=True)

reviews_df.isna().sum()
# Out:
# review_id             0
# product_id            0
# title                 0
# author                0
# rating                0
# content               0
# timestamp             0
# profile_id            0
# is_verified           0
# helpful_count         0
# product_attributes    0
# dtype: int64

# %%
#Descriptive Statistics of the dataframe:
reviews_df.describe()
# Out:
#             rating  helpful_count
# count  1200.000000    1200.000000
# mean      4.574167      24.003333
# std       0.670727     288.145432
# min       1.000000       0.000000
# 25%       4.000000       0.000000
# 50%       5.000000       0.000000
# 75%       5.000000       2.000000
# max       5.000000    9295.000000

# %%
#Calculating IQR for 'helpful_count':
Q1_helpful = reviews_df['helpful_count'].quantile(0.25)
Q3_helpful = reviews_df['helpful_count'].quantile(0.75)
IQR_helpful = Q3_helpful - Q1_helpful
lower_bound_helpful = Q1_helpful - 1.5 * IQR_helpful
upper_bound_helpful = Q3_helpful + 1.5 * IQR_helpful

#Identifying outliers in 'helpful_count':
outliers_helpful = reviews_df[(reviews_df['helpful_count'] < lower_bound_helpful) | (reviews_df['helpful_count'] > upper_bound_helpful)]

print("\nOutliers in 'helpful_count':")
print(outliers_helpful)
# Out:
# Outliers in 'helpful_count':
#            review_id  product_id  \
# 0     R20IRE5X6WY351  B085296FLT
# 1      RFGOLBEISEB55  B085296FLT
# 5     R2AGD67A8P04AC  B085296FLT
# 6     R1UVTRVZ4F5DME  B085296FLT
# 8     R1H100TYFQZJLK  B085296FLT
# ...              ...         ...
# 1131  R2P3JRB3XRYY3I  B0CCBKGDJD
# 1146   RWAWWHNPITXJD  B0CCBKGDJD
# 1174  R2RAY6TSYGNK51  B0CCBKGDJD
# 1178  R3TI36DXSKRHZM  B0CCBKGDJD
# 1180  R18SYH8M0MNZTT  B0CCBKGDJD
#
#                                                   title  \
# 0                  5.0 out of 5 stars Great headphones!
# 1                  5.0 out of 5 stars Great Headphones!
# 5     4.0 out of 5 stars Great headphones, just don'...
# 6                 5.0 out of 5 stars LONG battery life.
# 8         2.0 out of 5 stars Please Read Before Buying.
# ...                                                 ...
# 1131             4.0 out of 5 stars the best headphones
# 1146  4.0 out of 5 stars Unmatched Style and Perform...
# ...

# %% [markdown]
# The dataset includes 184 outliers in the helpful_count column, identified using the Interquartile Range (IQR) method. These outliers represent reviews that received an unusually
# high number of helpful votes compared to the majority of other reviews. Each outlier entry includes attributes such as review_id, product_id, title, author, rating, content,
# timestamp, profile_id, is_verified, helpful_count, and product_attributes.
#
# I chose not to handle these outliers in my analysis, opting instead to retain them in order to capture the full variability and potential insights they provide.

# %%
#Filtering rows based on rating greater than 3:
filtered_df = reviews_df[reviews_df['rating'] > 3]
filtered_df
# Out:
#            review_id  product_id  \
# 0     R20IRE5X6WY351  B085296FLT
# 1      RFGOLBEISEB55  B085296FLT
# 2     R2399XIITPW93N  B085296FLT
# 3     R1S3QWGEJLIK7Q  B085296FLT
# 4     R2T8PKNM1Q1XQK  B085296FLT
# ...              ...         ...
# 1195  R3OXSZT5T74ZFF  B0CCBKGDJD
# 1196  R1ZAEIMTC3EZGP  B0CCBKGDJD
# 1197  R35OTVSHNLWLNM  B0CCBKGDJD
# 1198  R1TSFDSW55DPVP  B0CCBKGDJD
# 1199  R382N0B8E1EZP4  B0CCBKGDJD
#
#                                                   title           author  \
# 0                  5.0 out of 5 stars Great headphones!   Talia Calazans
# 1                  5.0 out of 5 stars Great Headphones!  Leosha Williams
# 2                        5.0 out of 5 stars Works great      Max Rundell
# 3                 5.0 out of 5 stars amazing headphones              N/a
# 4                              5.0 out of 5 stars Whew!          I Allen
# ...                                                 ...              ...
# ...

# %%
#Sorting based on helpful_count:
sorted_df = reviews_df.sort_values(by='helpful_count', ascending=False)
sorted_df
# Out:
#            review_id  product_id  \
# 123   R2DOWUXMV1DC8N  B07Q9MJKBV
# 233   R3JI08GCH5LUUQ  B0863TXGM3
# 608   R1REYVNBG5AVBE  B07NM3RSRQ
# 226   R1ZFLY9RQPK84B  B0863TXGM3
# 108   R3AH4ZU7UTBZJ3  B07Q9MJKBV
# ...              ...         ...
# 594    RMQ9W6XNTHZDL  B094YV1S9T
# 595   R187X09SCNAI16  B094YV1S9T
# 597   R1Y6JGMGLXBSQI  B094YV1S9T
# 599   R22EDHWCG1N7TU  B094YV1S9T
# 1199  R382N0B8E1EZP4  B0CCBKGDJD
#
#                                                   title            author  \
# 123   1.0 out of 5 stars Surprisingly Unacceptable D...            achase
# 233   2.0 out of 5 stars Great sound, but several is...            Dennis
# 608   5.0 out of 5 stars There are no better BT head...        Carl Payne
# 226   5.0 out of 5 stars Comfort, noise canceling, a...             Pixel
# 108   4.0 out of 5 stars Non-Biased Review of Beats ...      Dave & Laura
# ...                                                 ...               ...
# ...

# %%
#Grouping the data based on the product's ASIN (product_id):
grouped_data = reviews_df.groupby('product_id')
grouped_data.first()
# Out:
#                  review_id                                              title  \
# product_id
# B075LT8YLR  R2DV19SUJ3ZQS1  5.0 out of 5 stars Great headphones for the pr...
# B07KY8G9NM  R2QN280Y807BEI                 5.0 out of 5 stars Good headphones
# B07NM3RSRQ  R350RH0BWMBO33  5.0 out of 5 stars Want ANC Headphones with $$...
# B07Q9MJKBV  R1ZIS9GF8Z8EGP  5.0 out of 5 stars Quiet the world without sac...
# B085296FLT  R20IRE5X6WY351               5.0 out of 5 stars Great headphones!
# B08629PFFQ   R7UEIYLC9RN57                5.0 out of 5 stars Great Headphones
# B0863TXGM3   RBAZBP0AEJ7MI   5.0 out of 5 stars A Bargain at this Price point
# B094YV1S9T  R3AS17JLHU5FXZ  5.0 out of 5 stars Love the quality for the pr...
# B09D3MFSGJ  R3UKK5538N3TM4      5.0 out of 5 stars DJ and cell phone friendly
# B09LYF2ST7   RIUMOOIYC2JV8  5.0 out of 5 stars Wonderful headphones, ESPEC...
# B0B7S1CY8J  R2Q9K387FISC8Q              5.0 out of 5 stars Perfect for teen!!
# ...

# %% [markdown]
# In Data Cleaning Process, I thoroughly explored the dataset's column datatypes, examined descriptive statistics to understand the data distribution, and identified outliers in key
# variables. I handled missing values by replacing them with 'Not Available' as the columns which had these null values were 'content', 'author', 'product_attributes' ensuring data
# integrity throughout the analysis.
#
# By retaining outliers, I aimed to capture the full range of variability in the dataset, which may provide valuable insights into exceptional cases or rare occurrences relevant to
# the analysis. This approach contributes to a more comprehensive understanding of the data and supports robust decision-making in subsequent analyses.

# %% [markdown]
# ## 5. Exploratory Data Analysis (EDA)
#
# ### 5.1 Data Overview

# %%
#Loading the dataset:

df = pd.read_csv('/content/drive/MyDrive/cleaned_dataset.csv')
df
# Out:
#            review_id  product_id  \
# 0     R20IRE5X6WY351  B085296FLT
# 1      RFGOLBEISEB55  B085296FLT
# 2     R2399XIITPW93N  B085296FLT
# 3     R1S3QWGEJLIK7Q  B085296FLT
# 4     R2T8PKNM1Q1XQK  B085296FLT
# ...              ...         ...
# 1195  R3OXSZT5T74ZFF  B0CCBKGDJD
# 1196  R1ZAEIMTC3EZGP  B0CCBKGDJD
# 1197  R35OTVSHNLWLNM  B0CCBKGDJD
# 1198  R1TSFDSW55DPVP  B0CCBKGDJD
# 1199  R382N0B8E1EZP4  B0CCBKGDJD
#
#                                                   title           author  \
# 0                  5.0 out of 5 stars Great headphones!   Talia Calazans
# 1                  5.0 out of 5 stars Great Headphones!  Leosha Williams
# 2                        5.0 out of 5 stars Works great      Max Rundell
# 3                 5.0 out of 5 stars amazing headphones              N/a
# 4                              5.0 out of 5 stars Whew!          I Allen
# ...                                                 ...              ...
# ...

# %%
#Providing descriptive statistics (mean, median, mode, variance, standard deviation):

#Calculating measures of central tendency for Rating column
mean_rating = df['rating'].mean()
median_rating = df['rating'].median()
mode_rating = df['rating'].mode()

#Calculating measures of data dispersion for Rating column
variance_rating = df['rating'].var()
std_rating = df['rating'].std()

#Calculating measures of data distribution for Rating column
quantiles_rating = df['rating'].quantile([0.25, 0.5, 0.75])

print("Mean Rating:", mean_rating)
print("Median Rating:", median_rating)
print("Mode Rating:", mode_rating)
print("Variance Rating:", variance_rating)
print("Standard Deviation Rating:", std_rating)
print("Quantiles Rating:", quantiles_rating)
# Out:
# Mean Rating: 4.574166666666667
# Median Rating: 5.0
# Mode Rating: 0    5
# Name: rating, dtype: int64
# Variance Rating: 0.4498742007228246
# Standard Deviation Rating: 0.6707266214508147
# Quantiles Rating: 0.25    4.0
# 0.50    5.0
# 0.75    5.0
# Name: rating, dtype: float64

# %% [markdown]
# Since 'rating' and 'helpful_count' are the only numerical columns in the dataframe, descriptive statistics—such as mean, median, and mode—can only be calculated for these columns.
# However, because analysis of the 'helpful_count' column may not be deemed useful, descriptive statistics are presented only for the 'rating' column.

# %% [markdown]
# ### 5.2 Visualizations

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
beats_product_ids = ['B085296FLT', 'B0CCBKGDJD']

#Filtering reviews based on product IDs:
beats_reviews = df[df['product_id'].isin(beats_product_ids)]
competitor_reviews = df[~df['product_id'].isin(beats_product_ids)]

# %%
# Add a column for labeling
beats_reviews['label'] = 'Beats'
competitor_reviews['label'] = 'Competitors'

# Concatenate the dataframes
all_ratings = pd.concat([beats_reviews, competitor_reviews])

# Plotting
sns.barplot(x='product_id', y='rating', hue='label', data= all_ratings )
plt.title('Distribution of Rating Comparison: Beats vs Competitors')
plt.xlabel('Product ID')
plt.ylabel('Average Rating')
plt.xticks(rotation=90)
plt.show()
# Out:
# <ipython-input-26-1aae7fd072f3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beats_reviews['label'] = 'Beats'
# <ipython-input-26-1aae7fd072f3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   competitor_reviews['label'] = 'Competitors'

# %% [markdown]
# *Observations* :
#
# - Beats Studio3 Headphones (Product ID: B085296FLT) consistently has high ratings, close to 5.
#
# - Beats Solo3 (Product ID: B0CCBKGDJD) shows a lower rating compared to B08529GFLT but still performs relatively well.
#
# - Competitors have a range of ratings, but many products from competitors are also rated highly, with several averaging close to or above 4.
#
# *Inferences* :
#
# - Beats products tend to have high customer satisfaction, especially Beats Studio3.
#
# - Competitors also have strong ratings, indicating that the market for these types of products is highly competitive with generally high satisfaction across the board.
#
# - The lower rating for Beats Solo3 might indicate specific areas for improvement for this product compared to other Beats products and competitor offerings.

# %%
#Creating subplots:
fig, axes = plt.subplots(1, 2, figsize=(15, 7), sharey=True)

#Plotting the rating distribution for Beats products:
sns.boxplot(ax=axes[0], x='product_attributes', y='rating', data=beats_reviews)
axes[0].set_title('Rating Distribution for Beats Products')
axes[0].set_xticklabels(axes[0].get_xticklabels(), rotation=90)

#Plotting the rating distribution for competitor products:
sns.boxplot(ax=axes[1], x='product_attributes', y='rating', data=competitor_reviews)
axes[1].set_title('Rating Distribution for Competitor Products')
axes[1].set_xticklabels(axes[1].get_xticklabels(), rotation=90)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-22-8ee3374ddb49>:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[0].set_xticklabels(axes[0].get_xticklabels(), rotation=90)
# <ipython-input-22-8ee3374ddb49>:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[1].set_xticklabels(axes[1].get_xticklabels(), rotation=90)

# %% [markdown]
# *Observations* :
#
# - Beats products show a concentrated range of high ratings with minimal outliers.
#
# - Competitor products display a wider distribution of ratings, with several products having more variation and more outliers.
#
# *Inferences* :
#
# - Beats products generally receive consistent high ratings, suggesting strong overall performance and customer satisfaction.
#
# - Competitors have more variability in their ratings, which could indicate a broader range of product quality or customer experiences.
#
# - The lack of significant outliers in Beats products suggests that there are fewer instances of extremely low ratings, which is a positive indicator for product reliability and performance.

# %%
#Plotting subplots
fig, axes = plt.subplots(1, 2, figsize=(15, 7), sharey=True)

#Plotting Box plot for Beats products:
sns.boxplot(ax=axes[0], x='product_attributes', y='helpful_count', data=beats_reviews)
axes[0].set_title('Helpful Count for Beats Products')
axes[0].set_xticklabels(axes[0].get_xticklabels(), rotation=90)

#Plotting a  Box plot for competitor products:
sns.boxplot(ax=axes[1], x='product_attributes', y='helpful_count', data=competitor_reviews)
axes[1].set_title('Helpful Count for Competitor Products')
axes[1].set_xticklabels(axes[1].get_xticklabels(), rotation=90)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-23-62555448f0e3>:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[0].set_xticklabels(axes[0].get_xticklabels(), rotation=90)
# <ipython-input-23-62555448f0e3>:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[1].set_xticklabels(axes[1].get_xticklabels(), rotation=90)

# %% [markdown]
# *Observation* :
# - Most of the product attributes have a low helpful count.
#
# - A few product attributes have extremely high outlier helpful counts, with some reviews having helpful counts reaching up to 8500.
#
# *Inference* :
#
# - The majority of the reviews are not marked as very helpful.
#
# - Certain product attributes tend to receive significantly more helpful votes, indicating that some products might be more engaging or have more detailed reviews.

# %% [markdown]
# ### 5.3 Descriptive Statistics

# %%
#Providing descriptive statistics (mean, median, mode, variance, standard deviation):

#Calculating measures of central tendency for Rating column
mean_rating = df['rating'].mean()
median_rating = df['rating'].median()
mode_rating = df['rating'].mode()

#Calculating measures of data dispersion for Rating column
variance_rating = df['rating'].var()
std_rating = df['rating'].std()

#Calculating measures of data distribution for Rating column
quantiles_rating = df['rating'].quantile([0.25, 0.5, 0.75])

print("Mean Rating:", mean_rating)
print("Median Rating:", median_rating)
print("Mode Rating:", mode_rating)
print("Variance Rating:", variance_rating)
print("Standard Deviation Rating:", std_rating)
print("Quantiles Rating:", quantiles_rating)
# Out:
# Mean Rating: 4.574166666666667
# Median Rating: 5.0
# Mode Rating: 0    5
# Name: rating, dtype: int64
# Variance Rating: 0.4498742007228246
# Standard Deviation Rating: 0.6707266214508147
# Quantiles Rating: 0.25    4.0
# 0.50    5.0
# 0.75    5.0
# Name: rating, dtype: float64

# %% [markdown]
# The statistical summary of the ratings provides valuable insights into the overall customer sentiment and satisfaction with the products reviewed. Here's a breakdown of what can be inferred from each metric:
#
# 1. **Mean Rating: 4.574**
#    - The mean (average) rating of 4.574 suggests that, on average, customers are quite satisfied with the products. A rating close to 5 indicates a generally positive reception, with many customers giving high ratings.
#
# 2. **Median Rating: 5.0**
#    - The median rating of 5.0, which represents the middle value in the sorted list of ratings, indicates that more than half of the customers gave the highest possible rating. This further supports the observation that customer satisfaction is generally high.
#
# 3. **Mode Rating: 5**
#    - The mode represents the most frequently occurring rating. In this case, the mode is 5, indicating that the majority of customers gave the highest possible rating. This concentration at the top end of the scale underscores the strong positive sentiment among customers.
#
# 4. **Variance Rating: 0.450**
#    - The variance measures the spread of the ratings around the mean. A variance of 0.450 indicates that the ratings are relatively close to the mean, suggesting a consistent level of satisfaction among customers. A low variance indicates less variation in customer opinions.
#
# 5. **Standard Deviation Rating: 0.671**
#    - The standard deviation provides a measure of the amount of variation or dispersion in the ratings. A standard deviation of 0.671 is relatively low, indicating that most ratings are close to the average, with few extreme values. This suggests consistent customer experiences across the products.
#
# 6. **Quantiles Rating:**
#    - **25th Percentile (Q1): 4.0** - 25% of the ratings are 4.0 or below.
#    - **50th Percentile (Median, Q2): 5.0** - 50% of the ratings are 5.0 or below.
#    - **75th Percentile (Q3): 5.0** - 75% of the ratings are 5.0 or below.
#
#    The quantiles show that a significant portion of the ratings are at the top end of the scale. Specifically, with both the median and the 75th percentile at 5.0, it is clear that the majority of customers are extremely satisfied, giving the highest rating possible.
#
# **Overall Inference:**
# The statistical analysis of the ratings reveals a generally high level of customer satisfaction with the products reviewed. The concentration of ratings around the maximum value (5.0), along with a low variance and standard deviation, indicates that customers consistently rate these products highly. This positive sentiment suggests that the products meet or exceed customer expectations, which is a strong indicator of product quality and customer approval.

# %% [markdown]
# ## 6. Sentiment Analysis
#
# ### 6.1 Methodology

# %% [markdown]
# In this project, sentiment analysis was conducted on the customer reviews to determine the overall sentiment towards Beats products compared to competitors. The sentiment analysis involved classifying the text data into positive, neutral, or negative categories.
#
# 1. TextBlob for Sentiment Analysis:
# We used the TextBlob library for sentiment analysis, which provides a simple API to perform common natural language processing (NLP) tasks, including sentiment classification. TextBlob uses a predefined set of rules and lexicons to assign a polarity score to text, which helps in determining the sentiment.
#
# 2. Segmenting the Data:
# The dataset was segmented into reviews for Beats products and competitor products to analyze the sentiments separately for each group.
#
# 3. Aggregating and Comparing Sentiments:
# The sentiment scores were aggregated to assess the overall consumer sentiment for both Beats and competitor products. The sentiment proportions were then compared and visualized.

# %%
from textblob import TextBlob

# Function to determine the sentiment of a review
def get_sentiment(text):
    analysis = TextBlob(text)
    if analysis.sentiment.polarity > 0:
        return 'positive'
    elif analysis.sentiment.polarity == 0:
        return 'neutral'
    else:
        return 'negative'

# Applying the sentiment function to each review
df['sentiment'] = df['content'].apply(get_sentiment)

# Segmenting the dataframe into Beats products and competitor products:
beats_reviews = df[df['product_id'].isin(beats_product_ids)]
competitor_reviews = df[~df['product_id'].isin(beats_product_ids)]

# Aggregating sentiment scores for Beats products:
beats_sentiment_counts = beats_reviews['sentiment'].value_counts()
beats_total_reviews = beats_reviews.shape[0]
beats_sentiment_proportions = beats_sentiment_counts / beats_total_reviews * 100

# Aggregating sentiment scores for Competitor products:
competitor_sentiment_counts = competitor_reviews['sentiment'].value_counts()
competitor_total_reviews = competitor_reviews.shape[0]
competitor_sentiment_proportions = competitor_sentiment_counts / competitor_total_reviews * 100

# Printing sentiment counts and proportions for Beats:
print("Beats Sentiment Counts:")
print(beats_sentiment_counts)
print("\nBeats Sentiment Proportions (%):")
print(beats_sentiment_proportions)

# Printing sentiment counts and proportions for Competitors:
print("\nCompetitor Sentiment Counts:")
print(competitor_sentiment_counts)
print("\nCompetitor Sentiment Proportions (%):")
print(competitor_sentiment_proportions)
# Out:
# Beats Sentiment Counts:
# sentiment
# positive    173
# neutral      18
# negative      9
# Name: count, dtype: int64
#
# Beats Sentiment Proportions (%):
# sentiment
# positive    86.5
# neutral      9.0
# negative     4.5
# Name: count, dtype: float64
#
# Competitor Sentiment Counts:
# sentiment
# positive    939
# neutral      35
# negative     26
# Name: count, dtype: int64
#
# Competitor Sentiment Proportions (%):
# sentiment
# positive    93.9
# neutral      3.5
# negative     2.6
# Name: count, dtype: float64

# %% [markdown]
# ### 6.2 Results
# Present the sentiment analysis results, including visualizations of sentiment distribution, and discuss the overall sentiment towards Beats by Dre products.

# %%
# Combining sentiment proportions into a single dataframe for plotting:
sentiment_comparison = pd.DataFrame({
    'Sentiment': ['Positive', 'Neutral', 'Negative'],
    'Beats': [beats_sentiment_proportions.get('positive', 0),
              beats_sentiment_proportions.get('neutral', 0),
              beats_sentiment_proportions.get('negative', 0)],
    'Competitors': [competitor_sentiment_proportions.get('positive', 0),
                    competitor_sentiment_proportions.get('neutral', 0),
                    competitor_sentiment_proportions.get('negative', 0)]
})

# Plotting sentiment comparison:
sentiment_comparison_melted = sentiment_comparison.melt(id_vars='Sentiment', var_name='Product_Type', value_name='Proportion')

plt.figure(figsize=(10, 6))
sns.barplot(x='Sentiment', y='Proportion', hue='Product_Type', data=sentiment_comparison_melted)
plt.title('Sentiment Comparison: Beats vs Competitors')
plt.ylabel('Proportion (%)')
plt.show()

# %% [markdown]
# *Observation* :
#
# - Both Beats and its competitors have a high proportion of positive reviews, with competitors having a slightly higher percentage.
#
# - Beats has a higher percentage of neutral reviews compared to its competitors.
#
# - Both Beats and its competitors have a low percentage of negative reviews, with Beats having a slightly higher percentage.
#
# *Inference* :
#
# - Both Beats and its competitors are generally well-regarded by customers. The slightly higher positive sentiment for competitors might suggest they are marginally preferred or have certain features that users appreciate more.
#
# - Beats may have more users who are indifferent or have a balanced view of the product. This could suggest variability in user experiences or unmet expectations in certain aspects of the product.
#
# - While negative sentiment is low overall, Beats may have slightly more areas where users are dissatisfied compared to its competitors. Identifying and addressing these areas could help improve overall user satisfaction.

# %% [markdown]
# ## 7. AI-Generated Insights
#
# ### 7.1 Using Gemini AI

# %% [markdown]
# **Using Gemini AI API for Insights Extraction**
#
# In the project, the **Gemini AI API** was leveraged to extract deeper insights from the dataset of customer reviews. The API provided advanced natural language processing (NLP) capabilities, allowing for a more nuanced understanding of the text data beyond basic sentiment analysis.
#
# ### How Gemini AI Was Used
#
# 1. **Advanced Sentiment Analysis:**
#    - While basic sentiment analysis categorized reviews into positive, neutral, or negative sentiments, Gemini AI offered more granular insights. It could identify specific aspects of the products mentioned in reviews (e.g., sound quality, design, battery life) and determine sentiment polarity for each aspect.
#
# 2. **Topic Modeling and Extraction:**
#    - Gemini AI was used to identify recurring themes and topics within the reviews. This helped in understanding what specific features or issues were most frequently discussed by customers, providing a more comprehensive view of consumer concerns and preferences.
#
# 3. **Contextual Analysis:**
#    - The API was also capable of understanding the context in which certain words or phrases were used. For example, it could differentiate between mentions of "noise" in the context of "noise-canceling" (positive) versus "background noise" (negative).
#
# 4. **Prompt-Based Insights:**
#    - Using predefined prompts, Gemini AI was queried to provide insights on specific questions. For instance, prompts like "What do customers think about the battery life of Beats products?" or "Highlight any common complaints about competitor products" enabled targeted analysis of the dataset.
#
# 5. **Aspect-Based Sentiment Analysis:**
#   - By focusing on specific product aspects, Gemini AI helped in identifying what customers liked or disliked about different product features. This detailed analysis allowed for more actionable insights compared to general sentiment analysis.
#
# 6. **Data-Driven Decision Making:**
#    - The insights gained from Gemini AI guided strategic decisions, such as product improvements and marketing strategies. Understanding customer sentiments about specific aspects enabled Beats to align their products more closely with consumer preferences and address any pain points.
#
#
# Overall, Gemini AI provided a powerful toolset for extracting and understanding complex customer sentiments, offering a competitive edge in consumer insights analysis.

# %% [markdown]
# ### 7.2 Key Insights

# %% [markdown]
# Following are some prompts that were used to generate insights:

# %%
import os

import google.generativeai as genai

# %%
#Prompt 1: To compare the following reviews to evaluate the sound quality of Beats products versus competitor products:

def analyze_reviews(reviews, api_key):
  genai.configure(api_key=api_key)
  generation_config = {
  "temperature": 1,
  "top_p": 0.95,
  "top_k": 64,
  "max_output_tokens": 8192,
  "response_mime_type": "text/plain",
  }

  model = genai.GenerativeModel(
  model_name="gemini-1.5-flash",
  generation_config=generation_config,
)

  chat_session = model.start_chat(history=[])

  prompt = "Compare the following reviews to evaluate the sound quality of Beats products versus competitor products:\n\n" + "\n\n".join(reviews)
  response = chat_session.send_message(prompt)
  return response.text

#Replacing api_key with actual api key
api_key='AIzaSyD7_KZ5i_sFgGrSlDy6qEGvMga-mNVbJTI'

#Select a subset of reviews
reviews = df['content'].tolist()

insights = analyze_reviews(reviews, api_key)

print(insights)
# Out:
# ## Beats vs. Competitors: A Sound Quality Analysis from Customer Reviews
#
# Based on the provided reviews, Beats products generally receive mixed reviews for their sound quality, with a strong emphasis on bass and a less-than-stellar reputation for clarity and detail. Here's a breakdown of the pros and cons for Beats versus competitor brands:
#
# **Beats:**
#
# **Pros:**
#
# * **Powerful bass:** Beats are consistently praised for their punchy, heavy bass, which many customers find enjoyable, particularly for genres like hip-hop and electronic music.
# * **Style and brand recognition:** Beats headphones often have a sleek, modern aesthetic and are associated with a certain image, which is a draw for some consumers.
# * **Good battery life:**  Several reviews highlight Beats' impressive battery life, which can last for several days with moderate use.
#
# **Cons:**
#
# ...

# %%
# Prompt 2: To assess customer satisfaction levels between Beats products and competitor products:

def analyze_reviews(reviews, api_key):
  genai.configure(api_key=api_key)
  generation_config = {
  "temperature": 1,
  "top_p": 0.95,
  "top_k": 64,
  "max_output_tokens": 8192,
  "response_mime_type": "text/plain",
  }

  model = genai.GenerativeModel(
  model_name="gemini-1.5-flash",
  generation_config=generation_config,
)

  chat_session = model.start_chat(history=[])

  prompt = "Compare the following reviews to assess customer satisfaction levels between Beats products and competitor products:\n\n" + "\n\n".join(reviews)
  response = chat_session.send_message(prompt)
  return response.text

#Replacing api_key with actual api key
api_key='AIzaSyD7_KZ5i_sFgGrSlDy6qEGvMga-mNVbJTI'

#Select a subset of reviews
reviews = df['content'].tolist()

insights = analyze_reviews(reviews, api_key)

print(insights)
# Out:
# ## Customer Satisfaction Comparison: Beats vs Competitors
#
# Based on the provided reviews, it's difficult to make a definitive conclusion about customer satisfaction levels solely comparing Beats products to competitors across the board.  However, some patterns emerge:
#
# **Beats:**
#
# * **Strengths:**
#     * **Style:** Beats products consistently receive praise for their sleek design and stylish aesthetics. Customers often cite the look as a key factor in their purchase decision.
#     * **Sound Quality:**  While the reviews highlight the "Beats" signature bass, there's also a general consensus of good sound quality, especially for those not seeking high-fidelity audio.
#     * **Value for Money:**  Many customers are happy with the price point, especially when Beats products are on sale.
#     * **Durability:**  Some users report long-term use of their Beats products, indicating reasonable durability.
# * **Weaknesses:**
# ...

# %%
# Prompt 3: To compare reviews to analyze the price-performance ratio of Beats products versus competitor products:

def analyze_reviews(reviews, api_key):
  genai.configure(api_key=api_key)
  generation_config = {
  "temperature": 1,
  "top_p": 0.95,
  "top_k": 64,
  "max_output_tokens": 8192,
  "response_mime_type": "text/plain",
  }

  model = genai.GenerativeModel(
  model_name="gemini-1.5-flash",
  generation_config=generation_config,
)

  chat_session = model.start_chat(history=[])

  prompt = "Compare the following reviews to analyze the price-performance ratio of Beats products versus competitor products:\n\n" + "\n\n".join(reviews)
  response = chat_session.send_message(prompt)
  return response.text

#Replacing api_key with actual api key
api_key='AIzaSyD7_KZ5i_sFgGrSlDy6qEGvMga-mNVbJTI'

#Select a subset of reviews
reviews = df['content'].tolist()

insights = analyze_reviews(reviews, api_key)

print(insights)
# Out:
# ## Beats vs. Competitors: Price-Performance Ratio Analysis
#
# Based on the provided reviews, it's clear that Beats products, particularly the Beats Studio3, face strong competition in terms of price-performance ratio. Here's a breakdown:
#
# **Beats Studio3:**
#
# * **Strengths:**
#     * Stylish and comfortable design (generally mentioned)
#     * Good sound quality (for casual listening, not audiophile)
#     * Decent battery life (varies, but mostly satisfactory)
#     * Apple integration is seamless (for iPhone users)
# * **Weaknesses:**
#     * Pricey (MSRP of $350 is generally considered too high)
#     * Noise cancellation is inconsistent and often criticized as underwhelming
#     * Build quality issues are reported (folding mechanism, earcup compression)
#     * Some complaints about touch controls being less intuitive and more prone to accidental activation
#     * Battery life can be inconsistent
#
# **Competitors:**
#
# * **Sony XM4/XM5:**
#     * **Strengths:**
# ...

# %% [markdown]
# ### 7.3 Interpretation

# %% [markdown]
# Beats headphones, including the Studio3 and Solo3 models, are praised for their stylish design, strong bass, and seamless Apple integration. However, they face criticism for ineffective noise cancellation, build quality issues, and high prices. The Studio3 model suffers from mediocre ANC and durability concerns, while the Solo3 lacks true noise cancellation and has comfort and durability issues. Common complaints across Beats products include poor build quality, uncomfortable fit, outdated Micro USB charging, and high cost relative to features. Competitors like Bose and Sony excel in noise cancellation and sound quality, while brands like Anker/Soundcore and TOZO offer strong value for money with competitive features.

# %% [markdown]
# ## 8. Comparative Analysis
#
# ### 8.1 Competitor Overview
# A brief overview of Beats' competitors and their market positioning:

# %% [markdown]
# 1. **Bose**
#    - **Overview:** Bose is a renowned audio equipment manufacturer known for its premium headphones, speakers, and sound systems. It has a strong market presence, especially in the high-end segment, and is known for its innovative noise-cancellation technology and superior sound quality.
#
# 2. **Sony**
#    - **Overview:** Sony is a global electronics giant with a significant presence in the audio market. It offers a wide range of headphones and speakers, catering to both premium and budget segments. Sony is known for its cutting-edge technology, including industry-leading noise cancellation and high-resolution audio.
#
# 3. **Beribes**
#    - **Overview:** Beribes is a lesser-known brand compared to the giants like Bose and Sony. It typically targets budget-conscious consumers, offering affordable audio products. The brand is positioned as a cost-effective alternative, providing decent quality for the price.
#
# 4. **Panasonic**
#    - **Overview:** Panasonic is a well-established electronics brand offering a variety of consumer electronics, including headphones and audio systems. It is positioned as a reliable mid-range option, known for delivering good quality and durability.
#
# 5. **JBL**
#    - **Overview:** JBL is a well-known brand specializing in audio equipment, particularly portable Bluetooth speakers and headphones. It appeals to a broad audience, offering products with vibrant sound and robust build quality. JBL is recognized for its stylish designs and value-for-money offerings.
#
# 6. **Soundcore (by Anker)**
#    - **Overview:** Soundcore, a brand by Anker, focuses on delivering high-quality audio products at affordable prices. It has gained a strong reputation for offering innovative features and good sound quality, making it popular among budget-conscious consumers looking for value.
#
# 7. **Doquas**
#    - **Overview:** Doquas is a relatively obscure brand in the global market, typically offering budget-friendly audio products. It positions itself as an affordable option for consumers who prioritize cost over brand recognition and premium features.
#
# 8. **Tozo**
#    - **Overview:** Tozo is known for its affordable range of wireless earbuds and headphones. It targets price-sensitive customers, providing good value for money with decent sound quality and features, often competing in the entry-level segment.
#
# 9. **Onedio**
#    - **Overview:** Onedio is another budget-friendly brand, offering a range of consumer electronics, including headphones. It primarily targets consumers looking for cost-effective solutions, with a focus on basic functionality and affordability.
#
# 10. **Avantree Ensemble**
#     - **Overview:** Avantree specializes in Bluetooth audio solutions, including headphones and transmitters. The brand is positioned towards consumers looking for specialized audio solutions, often catering to niche markets such as wireless audio for TVs and hearing aid compatibility.
#
# These competitors encompass a wide range of market positions, from premium brands like Bose and Sony to budget-friendly options like Tozo and Beribes. This diversity highlights the competitive landscape and varying consumer preferences in the audio product market.

# %% [markdown]
# ### 8.2 Comparison of Sentiments
# Compare the sentiment analysis results of Beats by Dre with its competitors using visualizations to highlight differences and similarities.

# %%
from textblob import TextBlob

# Function to determine the sentiment of a review
def get_sentiment(text):
    analysis = TextBlob(text)
    if analysis.sentiment.polarity > 0:
        return 'positive'
    elif analysis.sentiment.polarity == 0:
        return 'neutral'
    else:
        return 'negative'

# Applying the sentiment function to each review
df['sentiment'] = df['content'].apply(get_sentiment)

# Segmenting the dataframe into Beats products and competitor products:
beats_reviews = df[df['product_id'].isin(beats_product_ids)]
competitor_reviews = df[~df['product_id'].isin(beats_product_ids)]

# Aggregating sentiment scores for Beats products:
beats_sentiment_counts = beats_reviews['sentiment'].value_counts()
beats_total_reviews = beats_reviews.shape[0]
beats_sentiment_proportions = beats_sentiment_counts / beats_total_reviews * 100

# Aggregating sentiment scores for Competitor products:
competitor_sentiment_counts = competitor_reviews['sentiment'].value_counts()
competitor_total_reviews = competitor_reviews.shape[0]
competitor_sentiment_proportions = competitor_sentiment_counts / competitor_total_reviews * 100

# Printing sentiment counts and proportions for Beats:
print("Beats Sentiment Counts:")
print(beats_sentiment_counts)
print("\nBeats Sentiment Proportions (%):")
print(beats_sentiment_proportions)

# Printing sentiment counts and proportions for Competitors:
print("\nCompetitor Sentiment Counts:")
print(competitor_sentiment_counts)
print("\nCompetitor Sentiment Proportions (%):")
print(competitor_sentiment_proportions)
# Out:
# Beats Sentiment Counts:
# sentiment
# positive    173
# neutral      18
# negative      9
# Name: count, dtype: int64
#
# Beats Sentiment Proportions (%):
# sentiment
# positive    86.5
# neutral      9.0
# negative     4.5
# Name: count, dtype: float64
#
# Competitor Sentiment Counts:
# sentiment
# positive    939
# neutral      35
# negative     26
# Name: count, dtype: int64
#
# Competitor Sentiment Proportions (%):
# sentiment
# positive    93.9
# neutral      3.5
# negative     2.6
# Name: count, dtype: float64

# %%
# Combining sentiment proportions into a single dataframe for plotting:
sentiment_comparison = pd.DataFrame({
    'Sentiment': ['Positive', 'Neutral', 'Negative'],
    'Beats': [beats_sentiment_proportions.get('positive', 0),
              beats_sentiment_proportions.get('neutral', 0),
              beats_sentiment_proportions.get('negative', 0)],
    'Competitors': [competitor_sentiment_proportions.get('positive', 0),
                    competitor_sentiment_proportions.get('neutral', 0),
                    competitor_sentiment_proportions.get('negative', 0)]
})

# Plotting sentiment comparison:
sentiment_comparison_melted = sentiment_comparison.melt(id_vars='Sentiment', var_name='Product_Type', value_name='Proportion')

plt.figure(figsize=(10, 6))
sns.barplot(x='Sentiment', y='Proportion', hue='Product_Type', data=sentiment_comparison_melted)
plt.title('Sentiment Comparison: Beats vs Competitors')
plt.ylabel('Proportion (%)')
plt.show()

# %% [markdown]
# *Observation* :
#
# - Both Beats and its competitors have a high proportion of positive reviews, with competitors having a slightly higher percentage.
#
# - Beats has a higher percentage of neutral reviews compared to its competitors.
#
# - Both Beats and its competitors have a low percentage of negative reviews, with Beats having a slightly higher percentage.
#
# *Inference* :
#
# - Both Beats and its competitors are generally well-regarded by customers. The slightly higher positive sentiment for competitors might suggest they are marginally preferred or have certain features that users appreciate more.
#
# - Beats may have more users who are indifferent or have a balanced view of the product. This could suggest variability in user experiences or unmet expectations in certain aspects of the product.
#
# - While negative sentiment is low overall, Beats may have slightly more areas where users are dissatisfied compared to its competitors. Identifying and addressing these areas could help improve overall user satisfaction.

# %% [markdown]
# ### 8.3 SWOT Analysis

# %% [markdown]
# **Strengths:**
# 1. **Stylish Design:** Beats headphones are widely praised for their modern and stylish design, appealing to fashion-conscious consumers.
# 2. **Strong Bass:** The audio profile of Beats headphones, particularly the strong bass, is a key selling point and differentiator.
# 3. **Apple Integration:** Seamless integration with Apple devices enhances user experience, making Beats a popular choice among Apple users.
# 4. **Brand Recognition:** The Beats brand has strong recognition and appeal, especially among younger demographics.
#
# **Weaknesses:**
# 1. **Ineffective Noise Cancellation:** Compared to competitors like Bose and Sony, Beats' noise-cancellation features, particularly in models like the Studio3, are seen as less effective.
# 2. **Build Quality Issues:** Users frequently report concerns about the durability and build quality of Beats products, indicating potential reliability issues.
# 3. **Comfort Issues:** Some models, such as the Solo3, are criticized for being uncomfortable during extended use.
# 4. **High Price:** The cost of Beats headphones is often viewed as high relative to the features and quality offered, making them less appealing to price-sensitive consumers.
# 5. **Outdated Technology:** Features like Micro USB charging, which is considered outdated, can detract from the overall appeal of the products.
#
# **Opportunities:**
# 1. **Improving Noise Cancellation:** Enhancing noise-cancellation technology could significantly improve the competitive standing of Beats products.
# 2. **Addressing Build Quality and Comfort:** Improving the durability and comfort of the products could help mitigate some common complaints and enhance user satisfaction.
# 3. **Expanding Product Line:** Introducing new models or variants that offer different price points and features could appeal to a broader audience.
# 4. **Leveraging Brand Strength:** Building on the strong brand recognition and style appeal could help in marketing efforts and product positioning.
#
# **Threats:**
# 1. **Intense Competition:** Strong competitors like Bose and Sony, known for superior sound quality and noise cancellation, pose a significant threat.
# 2. **Value-for-Money Brands:** Brands like Anker/Soundcore and TOZO offer good quality at lower prices, appealing to cost-conscious consumers.
# 3. **Technological Advancements:** Rapid advancements in audio technology could leave Beats products behind if they do not keep up with industry trends.
# 4. **Changing Consumer Preferences:** Shifts in consumer preferences, such as increased demand for more durable and comfortable products, could negatively impact Beats if not addressed.

# %% [markdown]
# ## 9. Strategic Recommendations
#
# ### 9.1 Product Improvements

# %% [markdown]
# Based on the analysis, the following specific product improvements are suggested for Beats by Dre:
#
# 1. **Enhance Noise Cancellation Technology:**
#    - Invest in improving Active Noise Cancellation (ANC) across all product lines, particularly for models like the Studio3, where users report mediocre performance. Upgrading ANC technology can position Beats more competitively against industry leaders like Bose and Sony.
#
# 2. **Improve Build Quality and Durability:**
#    - Address common complaints about build quality by using higher-quality materials and more robust construction methods. Focus on reducing issues like cracking and wearing out, which detract from the overall product experience.
#
# 3. **Increase Comfort:**
#    - Redesign the fit and cushioning of headphones to enhance comfort during prolonged use. This could involve using softer, more breathable materials for ear pads and ensuring an adjustable and ergonomic headband design.
#
# 4. **Update Charging Technology:**
#    - Transition from outdated Micro USB charging to USB-C, aligning with modern standards and improving convenience for users. This update would also enhance charging speed and efficiency.
#
# 5. **Refine Audio Profile:**
#    - While strong bass is a signature feature, consider refining the audio profile to balance bass with mids and highs, appealing to a broader range of music preferences. This would cater to audiophiles and users looking for a more balanced sound experience.
#
# 6. **Expand Product Line and Features:**
#    - Introduce new models with varying feature sets and price points to appeal to a wider audience. Consider offering features like customizable sound profiles, better integration with non-Apple devices, and extended battery life.
#
# 7. **Enhance Product Differentiation:**
#    - Emphasize unique selling points like design and style in marketing, but also focus on differentiating features that add value. For example, integrating advanced audio technologies, exclusive Apple ecosystem features, or unique design collaborations could strengthen market position.
#
# 8. **Improve Customer Support and Warranty Policies:**
#    - Strengthen customer support and warranty policies to address issues quickly and efficiently. Offering extended warranties or guarantees on certain product aspects, like build quality, can reassure customers and improve brand loyalty.
#
# 9. **Incorporate User Feedback in Design Iterations:**
#    - Actively gather and incorporate user feedback into the design and feature set of new models. This approach ensures that the products meet the evolving needs and expectations of customers, enhancing user satisfaction and loyalty.

# %% [markdown]
# ### 9.2 Marketing Strategies

# %% [markdown]
# To enhance consumer perception and satisfaction for Beats by Dre, the following marketing strategies are recommended:
#
# ##### 1. **Leverage Product Improvements in Marketing Campaigns:**
#    - **Highlight Upgrades:** Emphasize recent improvements in noise cancellation, build quality, comfort, and technology in marketing materials. Use before-and-after comparisons to showcase the advancements made.
#    - **Feature Real-User Testimonials:** Share authentic reviews and testimonials from users who have experienced the enhancements firsthand.
#
# ##### 2. **Focus on Unique Selling Points:**
#    - **Design and Style:** Promote the stylish design and aesthetic appeal of Beats products. Use high-quality visuals and lifestyle imagery to highlight how the products fit into modern, fashionable lifestyles.
#    - **Apple Integration:** Leverage the seamless integration with Apple devices in marketing campaigns, particularly targeting Apple users who value this compatibility.
#
# ##### 3. **Implement Targeted Promotions and Discounts:**
#    - **Seasonal Sales:** Offer limited-time discounts during major sales events or product launches to attract new customers and incentivize purchases.
#    - **Bundle Offers:** Create bundles that include accessories or complementary products, such as carrying cases or charging docks, to add value and encourage higher spend.
#
# ##### 4. **Enhance Digital Presence and Engagement:**
#    - **Social Media Campaigns:** Run targeted social media campaigns focusing on user-generated content, influencer partnerships, and engaging visual content to connect with younger audiences.
#    - **Interactive Content:** Create interactive content such as polls, quizzes, or virtual try-ons to engage potential customers and provide a personalized experience.
#
# ##### 5. **Emphasize Customer Experience and Support:**
#    - **Customer Service Excellence:** Promote enhanced customer support and warranty policies in marketing materials to reassure potential buyers of a reliable and supportive purchase experience.
#    - **Loyalty Programs:** Develop and promote a loyalty program that rewards repeat customers with exclusive offers, discounts, or early access to new products.
#
# ##### 6. **Showcase Advanced Features and Innovations:**
#    - **Technology Demos:** Create video demonstrations or interactive web experiences that showcase advanced features like improved ANC, updated charging technology, or customizable sound profiles.
#    - **Comparative Ads:** Use comparative advertising to highlight how Beats products stand out from competitors in specific aspects, such as design, bass quality, or integration with Apple devices.
#
# ##### 7. **Engage with Influencers and Brand Ambassadors:**
#    - **Influencer Collaborations:** Partner with influencers and celebrities who align with Beats’ target audience to create authentic content and endorsements.
#    - **Brand Ambassadors:** Develop long-term relationships with brand ambassadors who can provide ongoing, credible endorsements and engage with their followers.
#
# ##### 8. **Utilize Data-Driven Insights for Personalization:**
#    - **Segmented Marketing:** Use data-driven insights to segment marketing efforts based on consumer preferences and behavior. Personalize messaging to address specific needs or concerns of different customer groups.
#    - **Feedback Integration:** Incorporate customer feedback into marketing strategies to address common concerns and highlight improvements in new campaigns.
#
# ##### 9. **Create Experiential Marketing Opportunities:**
#    - **Pop-Up Events:** Host pop-up events or experiential marketing campaigns where customers can experience the products firsthand and interact with the brand.
#    - **Product Trials:** Offer trial opportunities or demo units in key retail locations to allow potential customers to experience the product before purchasing.
#
# By implementing these strategies, Beats by Dre can enhance consumer perception, address areas of dissatisfaction, and strengthen its market position.

# %% [markdown]
# ### 9.3 Future Research

# %% [markdown]
# To further enhance the analysis and provide deeper insights, the following areas for future research or additional data collection are recommended:
#
# ##### 1. **Detailed Consumer Demographics:**
#    - **Collect Demographic Data:** Gather detailed demographic information (age, gender, income level, location) of reviewers to understand how different segments perceive and use Beats products compared to competitors.
#    - **Segment Analysis:** Analyze how different demographics respond to product features, pricing, and overall satisfaction to tailor marketing and product development strategies.
#
#
# ##### 2. **Longitudinal Analysis:**
#    - **Track Changes Over Time:** Collect data over a longer period to assess how customer sentiment and perceptions evolve with new product releases, improvements, or changes in market conditions.
#    - **Impact of Product Updates:** Measure the impact of product updates or marketing campaigns on consumer sentiment and satisfaction over time.
#
# ##### 3. **In-Depth Qualitative Analysis:**
#    - **Focus Groups:** Organize focus groups with current and potential users to gather qualitative insights into their preferences, expectations, and experiences with Beats products.
#
# ##### 4. **User Experience Research:**
#    - **Usability Studies:** Perform usability studies to assess how easy and intuitive it is for users to interact with Beats products, including setup, usage, and troubleshooting.
#    - **Customer Journey Mapping:** Map out the customer journey from awareness to purchase and post-purchase support to identify opportunities for improving the overall user experience.
#
# ##### 5. **Impact of Marketing Strategies:**
#    - **Campaign Effectiveness:** Analyze the effectiveness of different marketing campaigns and strategies in changing consumer perceptions and driving sales.
#    - **Brand Perception Studies:** Conduct studies to measure changes in brand perception and customer loyalty as a result of marketing efforts or product improvements.
#
# ##### 6. **Product Lifecycle Analysis:**
#    - **Lifecycle Stages:** Examine how consumer perceptions and preferences change throughout the product lifecycle, from introduction to maturity and eventual phase-out.
#    - **Replacement and Upgrade Patterns:** Investigate patterns in product replacement or upgrades to understand customer loyalty and the factors influencing their decision to switch brands.
#
# By pursuing these areas of research and collecting additional data, Beats by Dre can gain a more nuanced understanding of customer needs, market dynamics, and areas for potential growth and improvement.

# %% [markdown]
# ## 10. Conclusion

# %% [markdown]
# **Summary of Findings:**
#
# 1. **Strengths:**
#    - **Stylish Design and Strong Bass:** Beats headphones, including the Studio3 and Solo3 models, are widely praised for their aesthetic appeal and powerful bass performance.
#    - **Seamless Apple Integration:** The integration with Apple devices is a significant positive feature, enhancing convenience for users within the Apple ecosystem.
#
# 2. **Weaknesses:**
#    - **Ineffective Noise Cancellation:** Both the Studio3 and Solo3 models face criticism for subpar Active Noise Cancellation (ANC), with the Studio3 specifically noted for mediocre performance.
#    - **Build Quality Issues:** Common complaints include poor build quality, particularly related to hinges and cushions, leading to perceptions of fragility and discomfort.
#    - **High Pricing:** The high cost of Beats headphones is seen as a drawback compared to competitors offering similar or better features at lower prices.
#    - **Outdated Charging Technology:** The reliance on Micro USB charging is viewed as outdated compared to the more modern USB-C standard.
#
# 3. **Competitor Analysis:**
#    - **Bose and Sony:** These competitors excel in noise cancellation and sound quality, setting high standards in these areas.
#    - **Anker/Soundcore and TOZO:** These brands offer competitive features at lower prices, providing strong value for money.
#
# **Implications:**
#
# 1. **Product Improvement:**
#    - **Enhanced ANC:** Upgrading noise cancellation technology is crucial to remain competitive with leaders like Bose and Sony. Effective ANC will improve user satisfaction and address a major area of criticism.
#    - **Build Quality:** Investing in more durable materials and improved construction methods will address complaints and improve the overall perception of product quality.
#    - **Comfort and Fit:** Redesigning for better comfort will enhance user experience, particularly for prolonged use, and address comfort-related criticisms.
#    - **Modern Charging Technology:** Transitioning to USB-C will align Beats with current standards and improve user convenience.
#
# 2. **Market Positioning:**
#    - **Value Proposition:** Improving product features and quality can justify the premium pricing and strengthen the brand’s value proposition against competitors offering similar features at lower prices.
#    - **Customization and Features:** Offering advanced customization options can cater to diverse user preferences, differentiating Beats from competitors.
#
# 3. **Customer Experience:**
#    - **Enhanced Support:** Refining customer service and warranty processes will improve overall customer satisfaction and address issues more effectively.
#    - **Ongoing Engagement:** Continuously gathering and analyzing customer feedback will help in making informed decisions about product improvements and marketing strategies.
#
# **Reflection on the Overall Project:**
#
# The project aimed at providing Beats by Dre with insights into consumer sentiment by analyzing customer reviews. By gathering and examining feedback, the goal was to shed light on user experiences, preferences, and areas for improvement.
#
# **Contribution:**
#
# - **Enhanced Understanding:** The project aimed to deepen the understanding of consumer perceptions, highlighting both strengths and potential areas for enhancement in Beats products.
# - **Actionable Insights:** The findings were intended to offer recommendations for product improvements and marketing strategies, addressing user concerns and enhancing satisfaction.
# - **Strategic Direction:** The project sought to identify areas where Beats could enhance its competitive positioning, such as improving noise cancellation and build quality.
#
# Overall, this project aimed to provide Beats with valuable insights to inform their product development and market strategies.

# %% [markdown]
# ## 11. References

# %% [markdown]
# **Sources:**
#
# 1. **Amazon Reviews:** Data was gathered from Amazon product reviews for various Beats and competitor products.
# 2. **Oxylabs API:** Used for scraping reviews from Amazon and other review websites.
# 3. **Gemini AI API:** Employed for analyzing sentiment in the collected reviews.
#
# **Tools:**
#
# 1. **Python Libraries:**
#    - **Pandas:** For data manipulation and analysis.
#    - **NumPy:** For numerical operations and calculations.
#    - **Matplotlib & Seaborn:** For data visualization and plotting.
#    - **TextBlob/NLTK:** For sentiment analysis (if used in addition to Gemini AI API).
#    - **Scikit-learn:** For additional data processing or machine learning tasks (if applicable).
#
# 2. **Google Colab:** Used for executing Python code and scraping data with the provided notebook.
#
#
# **References:**
#
# 1. **Beats by Dre Official Website:** For product specifications and features.
# 2. **Competitor Websites:**
#    - **Bose:** [Official Website](https://www.bose.com)
#    - **Sony:** [Official Website](https://www.sony.com)
#    - **Anker/Soundcore:** [Official Website](https://www.soundcore.com)
#    - **TOZO:** [Official Website](https://www.tozo.com)
#    - **Panasonic:** [Official Website](https://www.panasonic.com)
#    - **JBL:** [Official Website](https://www.jbl.com)
#    - **Beribes:** [Official Website](https://www.beribes.com)
#    - **Doquas:** [Official Website](https://www.doquas.com)
#    - **Onedio:** [Official Website](https://www.onedio.com)
#    - **Avantree Ensemble:** [Official Website](https://www.avantree.com)

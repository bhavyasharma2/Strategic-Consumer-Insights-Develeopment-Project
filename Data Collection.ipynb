# %%
import json
import pandas as pd

# %%
file_path = '/content/data_beats_2.json'
with open(file_path, 'r') as file:
    data = json.load(file)

# %%
reviews_data = []
count = 0
for result in data['results']:
  asin = result['content']['asin']
  for review in result['content']['reviews']:
    count += 1
    try:
      review_info = {
      'review_id': review['id'],
      'product_id': asin,
      "title": review["title"],
      "author": review["author"],
      "rating": review["rating"],
      "content": review["content"],
      "timestamp": review["timestamp"],
      "profile_id": review["profile_id"],
      "is_verified": review["is_verified"],
      "helpful_count": review.get('helpful_count', 0),
      "product_attributes": review["product_attributes"]
      }
      reviews_data.append(review_info)
    except:
      print(count)
      break

reviews_df = pd.DataFrame(reviews_data)
reviews_df.to_csv('reviews_beats_2.csv', index=False)
reviews_df
# Out:
#          review_id  product_id  \
# 0    RAI90QWJQJF03  B0CCBKGDJD
# 1   R1MJ08QRWZKAK6  B0CCBKGDJD
# 2   R2IQV1A1SCQDVZ  B0CCBKGDJD
# 3    RB86XLAVC3GP7  B0CCBKGDJD
# 4   R2Z4K7Q4FQDJMI  B0CCBKGDJD
# ..             ...         ...
# 95  R3OXSZT5T74ZFF  B0CCBKGDJD
# 96  R1ZAEIMTC3EZGP  B0CCBKGDJD
# 97  R35OTVSHNLWLNM  B0CCBKGDJD
# 98  R1TSFDSW55DPVP  B0CCBKGDJD
# 99  R382N0B8E1EZP4  B0CCBKGDJD
#
#                                                 title             author  \
# 0   5.0 out of 5 stars Literally mind-blowing upgr...  Christian Waymire
# 1                 5.0 out of 5 stars My Go-to Headset         Amiyah Ogo
# 2   5.0 out of 5 stars These headphones deserve th...     Mariah Chapman
# 3           5.0 out of 5 stars 10/10, would buy again               Nala
# 4                         5.0 out of 5 stars Worth it              kwine
# ..                                                ...                ...
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_beats = pd.read_csv('/content/reviews_beats.csv')
df_comp_1 = pd.read_csv('/content/reviews_comp_1.csv')
df_comp_2 = pd.read_csv('/content/reviews_comp_2.csv')
df_comp_3 = pd.read_csv('/content/reviews_comp_3.csv')
df_comp_4 = pd.read_csv('/content/reviews_comp_4.csv')
df_comp_5 = pd.read_csv('/content/reviews_comp_5.csv')
df_comp_6 = pd.read_csv('/content/reviews_comp_6.csv')
df_comp_7 = pd.read_csv('/content/reviews_comp_7.csv')
df_comp_8 = pd.read_csv('/content/reviews_comp_8.csv')
df_comp_9 = pd.read_csv('/content/reviews_comp_9.csv')
df_comp_10 = pd.read_csv('/content/reviews_comp_10.csv')

# %%
merged_df = pd.concat([df_beats, df_comp_1, df_comp_2, df_comp_3, df_comp_4,df_comp_5, df_comp_6, df_comp_7, df_comp_8, df_comp_9, df_comp_10], ignore_index=True)
merged_df
# Out:
#            review_id  product_id  \
# 0     R20IRE5X6WY351  B085296FLT
# 1      RFGOLBEISEB55  B085296FLT
# 2     R2399XIITPW93N  B085296FLT
# 3     R1S3QWGEJLIK7Q  B085296FLT
# 4     R2T8PKNM1Q1XQK  B085296FLT
# ...              ...         ...
# 1095  R3H02YVS0QAFZJ  B08629PFFQ
# 1096  R2H4Y3M4Z4M3E7  B08629PFFQ
# 1097  R2NW0HFIMUURBN  B08629PFFQ
# 1098  R21FBJQG0LHRAK  B08629PFFQ
# 1099  R1AUWAUEQJZ1YJ  B08629PFFQ
#
#                                                   title           author  \
# 0                  5.0 out of 5 stars Great headphones!   Talia Calazans
# 1                  5.0 out of 5 stars Great Headphones!  Leosha Williams
# 2                        5.0 out of 5 stars Works great      Max Rundell
# 3                 5.0 out of 5 stars amazing headphones              N/a
# 4                              5.0 out of 5 stars Whew!          I Allen
# ...                                                 ...              ...
# ...

# %%
merged_df.to_csv('merged_reviews.csv', index=False)

# %%
pd.read_csv('/content/drive/MyDrive/merged_reviews.csv')
# Out:
#            review_id  product_id  \
# 0     R20IRE5X6WY351  B085296FLT
# 1      RFGOLBEISEB55  B085296FLT
# 2     R2399XIITPW93N  B085296FLT
# 3     R1S3QWGEJLIK7Q  B085296FLT
# 4     R2T8PKNM1Q1XQK  B085296FLT
# ...              ...         ...
# 1095  R3H02YVS0QAFZJ  B08629PFFQ
# 1096  R2H4Y3M4Z4M3E7  B08629PFFQ
# 1097  R2NW0HFIMUURBN  B08629PFFQ
# 1098  R21FBJQG0LHRAK  B08629PFFQ
# 1099  R1AUWAUEQJZ1YJ  B08629PFFQ
#
#                                                   title           author  \
# 0                  5.0 out of 5 stars Great headphones!   Talia Calazans
# 1                  5.0 out of 5 stars Great Headphones!  Leosha Williams
# 2                        5.0 out of 5 stars Works great      Max Rundell
# 3                 5.0 out of 5 stars amazing headphones              N/a
# 4                              5.0 out of 5 stars Whew!          I Allen
# ...                                                 ...              ...
# ...

# %%
reviews_df.to_csv('/content/drive/MyDrive/merged_reviews.csv', mode='a', header=False, index=False)

# %%
pd.read_csv('/content/drive/MyDrive/merged_reviews.csv')
# Out:
#            review_id  product_id  \
# 0     R20IRE5X6WY351  B085296FLT
# 1      RFGOLBEISEB55  B085296FLT
# 2     R2399XIITPW93N  B085296FLT
# 3     R1S3QWGEJLIK7Q  B085296FLT
# 4     R2T8PKNM1Q1XQK  B085296FLT
# ...              ...         ...
# 1195  R3OXSZT5T74ZFF  B0CCBKGDJD
# 1196  R1ZAEIMTC3EZGP  B0CCBKGDJD
# 1197  R35OTVSHNLWLNM  B0CCBKGDJD
# 1198  R1TSFDSW55DPVP  B0CCBKGDJD
# 1199  R382N0B8E1EZP4  B0CCBKGDJD
#
#                                                   title           author  \
# 0                  5.0 out of 5 stars Great headphones!   Talia Calazans
# 1                  5.0 out of 5 stars Great Headphones!  Leosha Williams
# 2                        5.0 out of 5 stars Works great      Max Rundell
# 3                 5.0 out of 5 stars amazing headphones              N/a
# 4                              5.0 out of 5 stars Whew!          I Allen
# ...                                                 ...              ...
# ...
